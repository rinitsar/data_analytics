# %% [markdown]
# # Regression Trees & Random Forest Regression

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import numpy as np
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_08

# %% [markdown]
# ## Import the apartment data

# %%
# Define columns for import
columns = [ 'web-scraper-order',
            'address_raw',
            'rooms',
            'area',
            'luxurious',
            'price',
            'price_per_m2',
            'lat',
            'lon',
            'bfs_number',
            'bfs_name',
            'pop',
            'pop_dens',
            'frg_pct',
            'emp',
            'mean_taxable_income',
            'dist_supermarket']

# Read and select variables
df_orig = pd.read_csv("apartments_data_enriched_cleaned.csv", sep=";", encoding='utf-8')[columns]

# Rename variable 'web-scraper-order' to 'apmt_id'
df_orig = df_orig.rename(columns={'web-scraper-order': 'id'})

# Remove missing values
df = df_orig.dropna()
df.head(5)

# Remove duplicates
df = df.drop_duplicates()

# Remove some 'extreme' values
df = df.loc[(df['price'] >= 1000) & 
            (df['price'] <= 5000)]

# Reset index
df = df.reset_index(drop=True)

print(df.shape)
df.head(5)
# Out:
# (722, 17)
#                id                           address_raw  rooms  area  \
# 0    1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0    49
# 1  1693998233-172   Widacherstrasse 5, 8630 Rüti ZH, ZH    3.0   111
# 2  1693998256-331         Widenweg 14, 8630 Rüti ZH, ZH    3.0    58
# 3  1693998265-381              Rain 1, 8630 Rüti ZH, ZH    4.0   118
# 4  1693998276-419  Bachtelstrasse 24b, 8630 Rüti ZH, ZH    3.0    66
#
#    luxurious  price  price_per_m2        lat       lon  bfs_number   bfs_name  \
# 0          0   1441         29.41  47.252171  8.845797         118  Rüti (ZH)
# 1          0   2600         23.42  47.252087  8.854919         118  Rüti (ZH)
# 2          0   1490         25.69  47.253670  8.853993         118  Rüti (ZH)
# 3          0   3240         27.46  47.259834  8.851705         118  Rüti (ZH)
# 4          0   1450         21.97  47.266113  8.866872         118  Rüti (ZH)
#
#      pop     pop_dens    frg_pct   emp  mean_taxable_income  dist_supermarket
# 0  12286  1221.272366  24.841283  5053          65362.04268        645.652248
# 1  12286  1221.272366  24.841283  5053          65362.04268        265.102153
# 2  12286  1221.272366  24.841283  5053          65362.04268         94.401821
# 3  12286  1221.272366  24.841283  5053          65362.04268        106.660970
# 4  12286  1221.272366  24.841283  5053          65362.04268        974.844209

# %% [markdown]
# ## Regression Tree
# See also: https://data36.com/regression-tree-python-scikit-learn

# %% [markdown]
# ### Create train and test samples for the regression tree (train = 80%, test = 20% of the data)

# %%
# Create train and test samples
X_train, X_test, y_train, y_test = train_test_split(df[['area', 
                                                        'rooms',
                                                        'pop_dens',
                                                        'mean_taxable_income',
                                                        'dist_supermarket']], 
                                                        df['price'], 
                                                        test_size=0.20, 
                                                        random_state=42)

# Show X_train
print('X_train:')
print(X_train.head(), '\n')

# Show y_train
print('y_train:')
print(y_train.head())
# Out:
# X_train:
#      area  rooms     pop_dens  mean_taxable_income  dist_supermarket
# 456   120    6.5   165.018625          65380.98802       1958.318650
# 6      65    3.5   525.662252         111422.35870        282.095910
# 362    90    3.5   424.146342          72133.75058       2606.231069
# 594    63    2.5  1044.628957          70964.08794        564.607066
# 439    91    3.5   399.525129          62000.54187        646.823905
#
# y_train:
# 456    1900
# 6      1850
# 362    2090
# 594    2102
# 439    1800
# Name: price, dtype: int64

# %% [markdown]
# ### Fit the regression tree model

# %%
# Create decision tree regressor object
reg = DecisionTreeRegressor(random_state=20, max_depth=3)

# Train decision tree regressor
reg = reg.fit(X_train, y_train)

# Predict the response for test dataset
y_pred = reg.predict(X_test)

# Calculate coefficient of determination (R-squared)
print('Task b - R-squared with max_depth=3:', r2_score(y_test, y_pred).round(4))
# Out:
# Task b - R-squared with max_depth=3: 0.4502

# %%
# Create decision tree regressor object with max_depth=5
reg = DecisionTreeRegressor(random_state=20, max_depth=5)

# Train decision tree regressor
reg = reg.fit(X_train, y_train)

# Predict the response for the test dataset
y_pred = reg.predict(X_test)

# Calculate coefficient of determination (R-squared)
print('Task b - R-squared with max_depth=5:', r2_score(y_test, y_pred).round(4))
# Out:
# Task b - R-squared with max_depth=5: 0.5247

# %% [markdown]
# ### Calculate coefficient of determination (R-squared)

# %%
# Calculate coefficient of determination
print('R-squared:', r2_score(y_test, y_pred).round(4))
# Out:
# R-squared: 0.5247

# %% [markdown]
# ### Print text representation of the regression tree

# %%
# Text representation of the regression tree
text_representation = tree.export_text(reg, 
                                       feature_names=list(X_train.columns))

# Print text_representation
print(text_representation)
# Out:
# |--- area <= 99.50
# |   |--- pop_dens <= 4269.10
# |   |   |--- area <= 77.50
# |   |   |   |--- rooms <= 1.25
# |   |   |   |   |--- area <= 35.50
# |   |   |   |   |   |--- value: [1153.83]
# |   |   |   |   |--- area >  35.50
# |   |   |   |   |   |--- value: [1325.00]
# |   |   |   |--- rooms >  1.25
# |   |   |   |   |--- area <= 69.50
# |   |   |   |   |   |--- value: [1698.66]
# |   |   |   |   |--- area >  69.50
# |   |   |   |   |   |--- value: [1884.28]
# |   |   |--- area >  77.50
# |   |   |   |--- mean_taxable_income <= 96728.41
# |   |   |   |   |--- pop_dens <= 1030.49
# |   |   |   |   |   |--- value: [1995.61]
# |   |   |   |   |--- pop_dens >  1030.49
# |   |   |   |   |   |--- value: [2257.40]
# |   |   |   |--- mean_taxable_income >  96728.41
# |   |   |   |   |--- mean_taxable_income <= 166929.42
# |   |   |   |   |   |--- value: [2604.00]
# |   |   |   |   |--- mean_taxable_income >  166929.42
# |   |   |   |   |   |--- value: [3055.00]
# |   |--- pop_dens >  4269.10
# |   |   |--- area <= 52.50
# |   |   |   |--- rooms <= 2.25
# |   |   |   |   |--- rooms <= 1.25
# |   |   |   |   |   |--- value: [1417.36]
# |   |   |   |   |--- rooms >  1.25
# |   |   |   |   |   |--- value: [1910.11]
# |   |   |   |--- rooms >  2.25
# |   |   |   |   |--- dist_supermarket <= 97.49
# |   |   |   |   |   |--- value: [1840.00]
# |   |   |   |   |--- dist_supermarket >  97.49
# |   |   |   |   |   |--- value: [2791.43]
# |   |   |--- area >  52.50
# |   |   |   |--- area <= 74.50
# |   |   |   |   |--- dist_supermarket <= 383.53
# |   |   |   |   |   |--- value: [2816.05]
# |   |   |   |   |--- dist_supermarket >  383.53
# |   |   |   |   |   |--- value: [2407.67]
# |   |   |   |--- area >  74.50
# |   |   |   |   |--- dist_supermarket <= 34.18
# |   |   |   |   |   |--- value: [4346.50]
# |   |   |   |   |--- dist_supermarket >  34.18
# |   |   |   |   |   |--- value: [3155.22]
# |--- area >  99.50
# |   |--- area <= 134.00
# |   |   |--- pop_dens <= 3874.83
# |   |   |   |--- area <= 109.50
# |   |   |   |   |--- mean_taxable_income <= 73029.70
# |   |   |   |   |   |--- value: [2408.48]
# |   |   |   |   |--- mean_taxable_income >  73029.70
# |   |   |   |   |   |--- value: [2659.10]
# |   |   |   |--- area >  109.50
# |   |   |   |   |--- area <= 126.50
# |   |   |   |   |   |--- value: [2869.60]
# |   |   |   |   |--- area >  126.50
# |   |   |   |   |   |--- value: [2408.89]
# |   |   |--- pop_dens >  3874.83
# |   |   |   |--- area <= 102.00
# |   |   |   |   |--- dist_supermarket <= 160.69
# |   |   |   |   |   |--- value: [4800.00]
# |   |   |   |   |--- dist_supermarket >  160.69
# |   |   |   |   |   |--- value: [3816.80]
# |   |   |   |--- area >  102.00
# |   |   |   |   |--- dist_supermarket <= 157.18
# |   |   |   |   |   |--- value: [2923.00]
# |   |   |   |   |--- dist_supermarket >  157.18
# |   |   |   |   |   |--- value: [3598.00]
# |   |--- area >  134.00
# |   |   |--- pop_dens <= 1663.59
# |   |   |   |--- rooms <= 5.00
# |   |   |   |   |--- area <= 170.50
# |   |   |   |   |   |--- value: [2895.50]
# |   |   |   |   |--- area >  170.50
# |   |   |   |   |   |--- value: [3735.00]
# |   |   |   |--- rooms >  5.00
# |   |   |   |   |--- mean_taxable_income <= 66444.23
# |   |   |   |   |   |--- value: [4800.00]
# |   |   |   |   |--- mean_taxable_income >  66444.23
# |   |   |   |   |   |--- value: [3480.91]
# |   |   |--- pop_dens >  1663.59
# |   |   |   |--- area <= 149.50
# |   |   |   |   |--- dist_supermarket <= 739.38
# |   |   |   |   |   |--- value: [3819.14]
# |   |   |   |   |--- dist_supermarket >  739.38
# |   |   |   |   |   |--- value: [4404.67]
# |   |   |   |--- area >  149.50
# |   |   |   |   |--- rooms <= 6.00
# |   |   |   |   |   |--- value: [4960.00]
# |   |   |   |   |--- rooms >  6.00
# |   |   |   |   |   |--- value: [4950.00]

# %% [markdown]
# ### Vizualizing the regression tree

# %%
fig = plt.figure(figsize=(12,6))
_ = tree.plot_tree(reg, 
                   feature_names=list(X_train.columns),  
                   class_names=['price'],
                   filled=True,
                   fontsize=9,
                   label='root',
                   rounded=True)

# %% [markdown]
# ### c)

# %%
X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
    df[['pop_dens', 'mean_taxable_income', 'dist_supermarket']], df['price'], test_size=0.20, random_state=42)


reg_c = DecisionTreeRegressor(random_state=20, max_depth=3)


reg_c = reg_c.fit(X_train_c, y_train_c)


y_pred_c = reg_c.predict(X_test_c)


print('Task c - R-squared without area and rooms:', r2_score(y_test_c, y_pred_c).round(4))
# Out:
# Task c - R-squared without area and rooms: 0.0504

# %% [markdown]
# ### e)

# %%
X2_train_e, X2_test_e, y2_train_e, y2_test_e = train_test_split(
    df[['rooms', 'pop_dens', 'mean_taxable_income', 'dist_supermarket']], df['price'], test_size=0.20, random_state=42)


cols_e = X2_train_e.columns


reg_rf_e = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=5)


reg_rf_e.fit(X2_train_e, y2_train_e)


importances_e = reg_rf_e.feature_importances_
indices_e = np.argsort(importances_e)[::-1]


print('Task e - Features after dropping area:')
print(cols_e[indices_e])
print(importances_e[indices_e])
# Out:
# Task e - Features after dropping area:
# Index(['rooms', 'dist_supermarket', 'mean_taxable_income', 'pop_dens'], dtype='object')
# [0.39736226 0.27042968 0.17860647 0.15360159]

# %% [markdown]
# ## Random Forest Regression
# For details see: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %% [markdown]
# ### Create train and test samples for the random forest (train = 80%, test = 20% of the data)

# %%
# Create train and test samples (the names X2_ and y2_ were used because X_ and y_ were already used above)
X2_train, X2_test, y2_train, y2_test = train_test_split(df[['area', 
                                                            'rooms',
                                                            'pop_dens',
                                                            'mean_taxable_income',
                                                            'dist_supermarket']], 
                                                            df['price'], 
                                                            test_size=0.20, 
                                                            random_state=42)

# Show X2_train
print('X2_train:')
print(X2_train.head(), '\n')

# Show y2_train
print('y2_train:')
print(y2_train.head())
# Out:
# X2_train:
#      area  rooms     pop_dens  mean_taxable_income  dist_supermarket
# 456   120    6.5   165.018625          65380.98802       1958.318650
# 6      65    3.5   525.662252         111422.35870        282.095910
# 362    90    3.5   424.146342          72133.75058       2606.231069
# 594    63    2.5  1044.628957          70964.08794        564.607066
# 439    91    3.5   399.525129          62000.54187        646.823905
#
# y2_train:
# 456    1900
# 6      1850
# 362    2090
# 594    2102
# 439    1800
# Name: price, dtype: int64

# %% [markdown]
# ### Fit the Random Forest Regression

# %%
X, y = make_regression(n_features=4, n_informative=2,
                       random_state=5, shuffle=False)


reg_rf = RandomForestRegressor(n_estimators=500, 
                               max_depth=10, 
                               random_state=5)
reg_rf.fit(X2_train, y2_train)

# Calculate coefficient of determination (R-squared)
print('R-squared:', reg_rf.score(X2_test, y2_test).round(4))
# Out:
# R-squared: 0.5481

# %% [markdown]
# ### Show feature importance

# %%
cols = X2_train.columns

# Derive feature importance from random forest
importances = reg_rf.feature_importances_
std         = np.std([tree.feature_importances_ for tree in reg_rf.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]

# Print col-names and importances-values
print( cols[indices] )
print( importances[indices] )

# Barplot with feature importance
df_fi = pd.DataFrame({'features':cols,'importances': importances})
df_fi.sort_values('importances', inplace=True)
df_fi.plot(kind='barh', 
           y='importances', 
           x='features', 
           color='darkred', 
           figsize=(6,3))

plt.show()
# Out:
# Index(['area', 'pop_dens', 'dist_supermarket', 'mean_taxable_income', 'rooms'], dtype='object')
# [0.56749536 0.16751781 0.11611526 0.09147853 0.05739305]

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1015-azure
# Datetime: 2023-11-13 13:30:09
# Python Version: 3.10.13
# -----------------------------------
